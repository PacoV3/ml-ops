# %%
import os
import sys
import numpy as np
from scipy.stats import randint
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold  # use for cross valbbidation
from sklearn.preprocessing import StandardScaler # for normalization
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectFromModel
from sklearn import metrics  # for the check the error of the model
from sklearn.metrics import mean_squared_error, r2_score

# Deep-learing
import keras
from keras.layers import Dense
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
import itertools
from keras.layers import LSTM
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Dropout

path = "power-consumption"
processed_path = os.path.join(path, ".processed")
processed_file = os.path.join(processed_path, "household-pow.csv")

# %%
df = pd.read_csv(processed_file, header=0, infer_datetime_format=True, parse_dates=["Date_time"], index_col=["Date_time"])
df.sort_values(by=["Date_time"], inplace=True)

# %%
df.head(3)
# Out:
#                      Global_active_power  Global_reactive_power  Voltage  \
# Date_time
# 2006-12-16 17:24:00                4.216                  0.418   234.84
# 2006-12-16 17:25:00                5.360                  0.436   233.63
# 2006-12-16 17:26:00                5.374                  0.498   233.29
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# Date_time
# 2006-12-16 17:24:00              18.4             0.0             1.0
# 2006-12-16 17:25:00              23.0             0.0             1.0
# 2006-12-16 17:26:00              23.0             0.0             2.0
#
#                      Sub_metering_3  Sub_metering_4
# Date_time
# 2006-12-16 17:24:00            17.0       52.266667
# 2006-12-16 17:25:00            16.0       72.333333
# 2006-12-16 17:26:00            17.0       70.566667

# %%
# Find all columns that have nan:
droping_list_all = []
for j in range(0, 8):
    if not df.iloc[:, j].notnull().all():
        droping_list_all.append(j)
droping_list_all
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
# Fill nan with mean in any columns
for j in range(0, 8):
    df.iloc[:, j] = df.iloc[:, j].fillna(df.iloc[:, j].mean())
df.isnull().sum()
# Out:
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# Sub_metering_4           0
# dtype: int64

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    dff = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(dff.shift(i))
        names += [("var%d(t-%d)" % (j + 1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(dff.shift(-i))
        if i == 0:
            names += [("var%d(t)" % (j + 1)) for j in range(n_vars)]
        else:
            names += [("var%d(t+%d)" % (j + 1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
## resampling of data over hour
df_resample = df.resample("h").mean()
df_resample.shape
# Out:
# (34951, 8)

# %%
# values = df.values
values = df_resample.values 
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)   
# drop columns we don't want to predict
reframed.drop(reframed.columns[[9,10,11,12,13,14,15]], axis=1, inplace=True)
reframed.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.636816   0.295738   0.337945   0.631157        0.0   0.011366
# 2   0.545045   0.103358   0.335501   0.541487        0.0   0.144652
# 3   0.509006   0.110073   0.283801   0.502152        0.0   0.030869
# 4   0.488550   0.096987   0.315988   0.481110        0.0   0.000000
# 5   0.455597   0.099010   0.434417   0.449904        0.0   0.008973
#
#    var7(t-1)  var8(t-1)   var1(t)
# 1   0.782418   0.813346  0.545045
# 2   0.782676   0.560592  0.509006
# 3   0.774169   0.585814  0.488550
# 4   0.778809   0.572244  0.455597
# 5   0.798917   0.503143  0.322555

# %%
# split into train and test sets
values = reframed.values

n_train_time = 365*24
train = values[:n_train_time, :]
test = values[n_train_time:, :]
# test = values[n_train_time:n_test_time, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape) 
# We reshaped the input into the 3D format as expected by LSTMs, namely [samples, timesteps, features].
# Out:
# (8760, 1, 8) (8760,) (25816, 1, 8) (25816,)

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.2))
# model.add(LSTM(70), input_shape=(train_X.shape[1], train_X.shape[2])))
# model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss="mean_squared_error", optimizer="adam")

# %%
# fit network
history = model.fit(
    train_X,
    train_y,
    epochs=20,
    batch_size=70,
    validation_data=(test_X, test_y),
    verbose=2,
    shuffle=False,
)
# Out:
# Epoch 1/20
# 126/126 - 2s - loss: 0.0188 - val_loss: 0.0112 - 2s/epoch - 20ms/step
# Epoch 2/20
# 126/126 - 1s - loss: 0.0114 - val_loss: 0.0093 - 952ms/epoch - 8ms/step
# Epoch 3/20
# 126/126 - 1s - loss: 0.0107 - val_loss: 0.0090 - 798ms/epoch - 6ms/step
# Epoch 4/20
# 126/126 - 1s - loss: 0.0105 - val_loss: 0.0090 - 829ms/epoch - 7ms/step
# Epoch 5/20
# 126/126 - 1s - loss: 0.0105 - val_loss: 0.0090 - 806ms/epoch - 6ms/step
# Epoch 6/20
# 126/126 - 1s - loss: 0.0105 - val_loss: 0.0091 - 791ms/epoch - 6ms/step
# Epoch 7/20
# 126/126 - 1s - loss: 0.0105 - val_loss: 0.0091 - 793ms/epoch - 6ms/step
# Epoch 8/20
# 126/126 - 1s - loss: 0.0104 - val_loss: 0.0092 - 853ms/epoch - 7ms/step
# Epoch 9/20
# 126/126 - 1s - loss: 0.0104 - val_loss: 0.0092 - 860ms/epoch - 7ms/step
# Epoch 10/20
# 126/126 - 1s - loss: 0.0104 - val_loss: 0.0092 - 777ms/epoch - 6ms/step
# Epoch 11/20
# 126/126 - 1s - loss: 0.0104 - val_loss: 0.0093 - 759ms/epoch - 6ms/step
# Epoch 12/20
# 126/126 - 1s - loss: 0.0104 - val_loss: 0.0093 - 854ms/epoch - 7ms/step
# Epoch 13/20
# 126/126 - 1s - loss: 0.0104 - val_loss: 0.0092 - 821ms/epoch - 7ms/step
# Epoch 14/20
# 126/126 - 1s - loss: 0.0103 - val_loss: 0.0092 - 716ms/epoch - 6ms/step
# Epoch 15/20
# 126/126 - 1s - loss: 0.0103 - val_loss: 0.0092 - 775ms/epoch - 6ms/step
# Epoch 16/20
# 126/126 - 1s - loss: 0.0103 - val_loss: 0.0092 - 805ms/epoch - 6ms/step
# Epoch 17/20
# 126/126 - 1s - loss: 0.0103 - val_loss: 0.0092 - 764ms/epoch - 6ms/step
# Epoch 18/20
# 126/126 - 1s - loss: 0.0103 - val_loss: 0.0092 - 751ms/epoch - 6ms/step
# Epoch 19/20
# 126/126 - 1s - loss: 0.0103 - val_loss: 0.0092 - 827ms/epoch - 7ms/step
# Epoch 20/20
# 126/126 - 1s - loss: 0.0103 - val_loss: 0.0092 - 939ms/epoch - 7ms/step

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
# summarize history for loss
fig = plt.subplots(1, 1, figsize=(20, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# make a prediction
yhat = model.predict(test_X)
new_test_X = test_X.reshape((test_X.shape[0], 8))
# invert scaling for forecast
inv_yhat = np.concatenate((yhat, new_test_X[:, -7:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, 0]
# invert scaling for actual
new_test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((new_test_y, new_test_X[:, -7:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, 0]
# calculate RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print("Test RMSE: %.3f" % rmse)
# Out:
# Test RMSE: 0.618

# %%
inv_y.shape, inv_yhat.shape
# Out:
# ((25816,), (25816,))

# %%
time_val = 730
x_count = [x for x in range(time_val)]
plt.figure(figsize=(20, 5))
plt.plot(x_count, inv_y[:time_val], marker=".", label="actual")
plt.plot(x_count, inv_yhat[:time_val], "r", label="prediction")
plt.ylabel(df.columns[0], size=15)
plt.xlabel(f"Time step for the first {time_val} hours", size=15)
plt.legend(fontsize=15)
plt.show()

# %%
# serialize the model to disk
model.save('first_year_hourly.model', save_format="h5")
